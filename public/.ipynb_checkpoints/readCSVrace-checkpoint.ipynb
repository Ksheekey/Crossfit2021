# %%
import csv
import pandas as pd
import json
import timeit

# start program run timer
start = timeit.default_timer()

# %%
CSV = pd.read_csv('crossfit0neDivision.csv')

# %%
CSV = CSV[:74]

# %%
CSV = CSV[['full_name', 'Event_1_race', 'Event_2_race', 'Event_3_race',
     'Event_4_race', 'Event_5_race', 'Event_6_race', 'Event_7_race',
     'Event_8_race', 'Event_9_race', 'Event_10_race', 'Event_11_race',
     'Event_12_race', 'Event_13_race', 'Event_14_race', 'Event_15_race']]

# %%
data = {}
allData = {}
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
list7 = []
list8 = []
list9 = []
list10 = []
list11 = []
list12 = []
list13 = []
list14 = []
list15 = []
x = 1
y = 0

for index, row in CSV.iterrows():
    list1.append({"athlete": row['full_name'], "score": row['Event_1_race']})
    allData[1] = list1
    list2.append({"athlete": row['full_name'], "score": row['Event_2_race']})
    allData[2] = list2
    list3.append({"athlete": row['full_name'], "score": row['Event_3_race']})
    allData[3] = list3
    list4.append({"athlete": row['full_name'], "score": row['Event_4_race']})
    allData[4] = list4
    list5.append({"athlete": row['full_name'], "score": row['Event_5_race']})
    allData[5] = list5
    list6.append({"athlete": row['full_name'], "score": row['Event_6_race']})
    allData[6] = list6
    list7.append({"athlete": row['full_name'], "score": row['Event_7_race']})
    allData[7] = list7
    list8.append({"athlete": row['full_name'], "score": row['Event_8_race']})
    allData[8] = list8
    list9.append({"athlete": row['full_name'], "score": row['Event_9_race']})
    allData[9] = list9
    list10.append({"athlete": row['full_name'], "score": row['Event_10_race']})
    allData[10] = list10
    list11.append({"athlete": row['full_name'], "score": row['Event_11_race']})
    allData[11] = list11
    list12.append({"athlete": row['full_name'], "score": row['Event_12_race']})
    allData[12] = list12
    list13.append({"athlete": row['full_name'], "score": row['Event_13_race']})
    allData[13] = list13
    list14.append({"athlete": row['full_name'], "score": row['Event_14_race']})
    allData[14] = list14
    list15.append({"athlete": row['full_name'], "score": row['Event_15_race']})
    allData[15] = list15

    
allData
# Out:
# {1: [{'athlete': 'Justin Medeiros', 'score': 185.0},
#   {'athlete': 'Tia-Clair Toomey', 'score': 188.0},
#   {'athlete': 'Patrick Vellner', 'score': 33.0},
#   {'athlete': 'Saxon Panchik', 'score': 107.0},
#   {'athlete': 'Bjorgvin Karl Gudmundsson', 'score': 176.0},
#   {'athlete': 'Brent Fikowski', 'score': 161.0},
#   {'athlete': 'Jonne Koski', 'score': 200.0},
#   {'athlete': 'Laura Horvath', 'score': 155.0},
#   {'athlete': 'Guilherme Malheiros', 'score': 95.0},
#   {'athlete': 'Alex Vigneault', 'score': 194.0},
#   {'athlete': 'Noah Ohlsen', 'score': 119.0},
#   {'athlete': 'Lazar Dukic', 'score': 197.0},
#   {'athlete': 'Annie Thorisdottir', 'score': 73.0},
#   {'athlete': 'Jeffrey Adler', 'score': 98.0},
#   {'athlete': 'Kristin Holte', 'score': 131.0},
#   {'athlete': 'Scott Panchik', 'score': 86.0},
#   {'athlete': 'Travis Mayer', 'score': 143.0},
#   {'athlete': 'Cole Sager', 'score': 122.0},
#   {'athlete': 'Andre Houdet', 'score': 125.0},
# ...

# %%
with open('allData.json', 'w') as f:
    json.dump(allData, f)

# %%
# stop program run timer
stop = timeit.default_timer()

print('Time to run:', stop - start)
# Out:
# Time to run: 0.25248152200000007
